# %% [markdown]
# # <center>Cars Data Analysis</center>

# %% [markdown]
# #### Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("cars.csv")
df.head()
# Out:
#                     carname fueltype aspiration doornumber      carbody
# 0        alfa-romero giulia      gas        std        two  convertible  \
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginesize
# 0        rwd          front       88.6      168.8      64.1  ...       130.0  \
# 1        rwd          front       88.6      168.8      64.1  ...       130.0
# 2        rwd          front       94.5      171.2      65.5  ...       152.0
# 3        fwd          front       99.8      176.6      66.2  ...       109.0
# 4        4wd          front       99.4      176.6      66.4  ...       136.0
#
# ...

# %%
df.isnull().sum()
# Out:
# carname              0
# fueltype             0
# aspiration           0
# doornumber           0
# carbody              0
# drivewheel           0
# enginelocation       0
# wheelbase           11
# carlength            0
# carwidth            20
# carheight           15
# curbweight           0
# enginetype           0
# cylindernumber       0
# enginesize          20
# fuelsystem           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %%
df.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight
# count  194.000000  205.000000  185.000000  190.000000   205.000000  \
# mean    98.669588  174.049268   65.932973   53.738947  2555.565854
# std      5.934168   12.337289    2.113143    2.470452   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.200000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    101.800000  183.100000   66.600000   55.575000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginesize   boreratio      stroke  compressionratio  horsepower
# count  185.000000  205.000000  205.000000        205.000000  205.000000  \
# mean   124.081081    3.329756    3.255415         10.142537  104.117073
# std     38.528771    0.270844    0.313597          3.972040   39.544167
# min     61.000000    2.540000    2.070000          7.000000   48.000000
# ...

# %% [markdown]
# #### Que #1: Find the population mean and standard deviation for peakrpm column.

# %%
pop_mean = df['peakrpm'].mean()
pop_std = df['peakrpm'].std()

print("The population mean is", pop_mean)
print("The population standard deviation is", pop_std)
# Out:
# The population mean is 5125.121951219512
# The population standard deviation is 476.98564305694634

# %% [markdown]
# #### Que #2: Draw a sample of 30 from the population of peakrpm column and calculate the sample mean and standard deviation.

# %%
sample = df.sample(n=30, random_state=1)

# %%
sample_mean = sample['peakrpm'].mean()
sample_std = sample['peakrpm'].std()

print("The sample mean is", sample_mean)
print("The sample standard deviation is", sample_std)
# Out:
# The sample mean is 5255.0
# The sample standard deviation is 500.4050083820036

# %% [markdown]
# #### Que #3: Calculate the margin of error for 95% confidence level for peakrpm using standard deviation of sample.

# %%
n = 30
z_critical = stats.norm.ppf(q=0.95)

margin_of_error = z_critical * (sample_std / n**0.5)
print("The margin of error is", margin_of_error)
# Out:
# The margin of error is 150.27553306019482

# %% [markdown]
# #### Que #4: Calculate confidence interval for the peakrpm.

# %%
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
print("The confidence interval is", confidence_interval)
# Out:
# The confidence interval is (5104.724466939805, 5405.275533060195)
